# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/nidhipareddy/Desktop/uchicago/WA_Fn-UseC_-HR-Employee-Attrition (1).csv")

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department
# 0   41       Yes      Travel_Rarely       1102                   Sales  \
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber
# 0                 1          2  Life Sciences              1               1  \
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel
# ...

# %%
print("Dataset Overview:")
print(df.info())
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %%
print("\nSummary Statistics:")
print(df.describe(include="all"))

##looks like dont have nulls
# Out:
# Summary Statistics:
#                 Age Attrition BusinessTravel    DailyRate
# count   1470.000000      1470           1470  1470.000000  \
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField
# count                     1470       1470.000000  1470.000000           1470  \
# unique                       3               NaN          NaN              6
# ...

# %%
missing_values = df.isnull().sum()
print("\nMissing Values:\n", missing_values[missing_values > 0])
# Out:
# Missing Values:
#  Series([], dtype: int64)

# %%
num_cols = df.select_dtypes(include=['number']).columns
cat_cols = df.select_dtypes(include=['object']).columns

#numerical plot columns
for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# /var/folders/df/brscn_097k58xvwsqc87cx240000gn/T/ipykernel_4428/931444325.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], order=df[col].value_counts().index, palette="coolwarm")
# /var/folders/df/brscn_097k58xvwsqc87cx240000gn/T/ipykernel_4428/931444325.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], order=df[col].value_counts().index, palette="coolwarm")
# /var/folders/df/brscn_097k58xvwsqc87cx240000gn/T/ipykernel_4428/931444325.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
#catagorical varables plots
for col in cat_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=df[col], order=df[col].value_counts().index, palette="coolwarm")
    plt.xticks(rotation=45)
    plt.title(f'Count Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()
# Out:
# /var/folders/df/brscn_097k58xvwsqc87cx240000gn/T/ipykernel_4428/244732129.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], order=df[col].value_counts().index, palette="coolwarm")
# /var/folders/df/brscn_097k58xvwsqc87cx240000gn/T/ipykernel_4428/244732129.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], order=df[col].value_counts().index, palette="coolwarm")
# /var/folders/df/brscn_097k58xvwsqc87cx240000gn/T/ipykernel_4428/244732129.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# 7. Correlation Heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# 8. Boxplots to Identify Outliers
for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
if 'Attrition' in df.columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(x='Attrition', data=df, palette='coolwarm')
    plt.title("Attrition Count")
    plt.show()

    # Attrition vs Other Categorical Columns
    for col in cat_cols:
        if col != "Attrition":
            plt.figure(figsize=(6, 4))
            sns.countplot(x=df[col], hue=df["Attrition"], palette="coolwarm")
            plt.xticks(rotation=45)
            plt.title(f'Attrition by {col}')
            plt.show()
# Out:
# /var/folders/df/brscn_097k58xvwsqc87cx240000gn/T/ipykernel_4428/3328915650.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Attrition', data=df, palette='coolwarm')
